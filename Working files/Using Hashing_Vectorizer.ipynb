# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
file_name2='C:/Users/ostina/Documents/ES/fianl/funcom_processed/dump/comment.csv'
file_name1='C:/Users/ostina/Documents/ES/fianl/funcom_processed/dump/functions.csv'

# %%
file1 = open(file_name1, "r",encoding="utf8")
file2 = open(file_name2, "r",encoding="utf8")

# %%
# list of text documents
text = file1
# create the transform
vectorizer = HashingVectorizer(n_features=150)
# encode document
vector = vectorizer.transform(text)
# summarize encoded vector
print(vector.shape)
X=vector.toarray()
# Out:
# (120, 150)

# %%
# list of text documents
text = file2
# create the transform
vectorizer = HashingVectorizer(n_features=1)
# encode document
vector = vectorizer.transform(text)
# summarize encoded vector
print(vector.shape)
y=vector.toarray()
# Out:
# (120, 1)

# %%
m,n =X.shape

# %%
import numpy as np
from scipy.sparse import csr_matrix
import pandas as pd

X1=X*100
X1=X1.astype(int)
y1=y*100
y1=y1.astype(int)
print(X1.shape)
print(y1.shape)
print(y1)
m,n =X1.shape
print(m,n)
# Out:
# (120, 150)
# (120, 1)
# [[-100]
#  [-100]
#  [ 100]
#  [ 100]
#  [ 100]
#  [   0]
#  [   0]
#  [   0]
#  [ 100]
#  [-100]
#  [-100]
#  [ 100]
#  [   0]
#  [-100]
#  [   0]
#  [-100]
#  [ 100]
#  [ 100]
#  [   0]
#  [   0]
#  [ 100]
#  [-100]
#  [-100]
#  [-100]
#  [   0]
#  [   0]
#  [   0]
#  [ 100]
#  [-100]
#  [-100]
#  [   0]
#  [   0]
#  [ 100]
#  [ 100]
#  [-100]
#  [ 100]
#  [ 100]
#  [ 100]
#  [ 100]
#  [-100]
#  [ 100]
#  [-100]
#  [   0]
#  [-100]
#  [ 100]
#  [-100]
#  [   0]
#  [-100]
#  [ 100]
#  [-100]
#  [-100]
#  [ 100]
#  [-100]
#  [ 100]
#  [ 100]
#  [ 100]
#  [-100]
#  [ 100]
#  [-100]
#  [ 100]
#  [ 100]
#  [ 100]
#  [-100]
#  [-100]
#  [-100]
#  [-100]
#  [   0]
#  [-100]
#  [-100]
#  [-100]
#  [   0]
#  [-100]
#  [ 100]
#  [ 100]
#  [ 100]
#  [ 100]
#  [ 100]
#  [-100]
#  [ 100]
#  [-100]
#  [ 100]
#  [   0]
#  [ 100]
#  [   0]
#  [-100]
#  [   0]
#  [ 100]
#  [ 100]
#  [-100]
#  [ 100]
#  [-100]
#  [-100]
#  [ 100]
#  [ 100]
#  [ 100]
#  [ 100]
#  [ 100]
# ...

# %%
X_dev = X1[0:20].T
Y_dev = y1[0:20].T

X_train=X1[31:120]
X_train=X_train.T
Y_train = y1[31:120]


_,m_train = X_train.shape

# %%
X_train = X1.T
Y_train = y1
_,m_train = X_train.shape

# %%
def init_params():
    W1 = np.random.rand(150, 150) - 0.5
    b1 = np.random.rand(150, 1) - 0.5
    W2 = np.random.rand(150, 150) - 0.5
    b2 = np.random.rand(150, 1) - 0.5
    return W1, b1, W2, b2

def ReLU(Z):
    
    return np.maximum(Z, 0)

def softmax(Z):
    A = np.exp(Z) / sum(np.exp(Z))
    return A
    
def forward_prop(W1, b1, W2, b2, X):
    Z1 = W1.dot(X) + b1
    A1 = ReLU(Z1)
    Z2 = W2.dot(A1) + b2
    A2 = softmax(Z2)
    return Z1, A1, Z2, A2

def ReLU_deriv(Z):
    return Z > 0

def one_hot(Y):
    one_hot_Y = np.zeros((Y.size, Y.max() + 1))
    #print(one_hot_Y.shape)
    one_hot_Y[np.arange(Y.size), Y] = 1
    one_hot_Y = one_hot_Y.T
    return one_hot_Y

def backward_prop(Z1, A1, Z2, A2, W1, W2, X, Y):
    #one_hot_Y = one_hot(Y)
    dZ2 = A2 - Y.T#one_hot_Y
    dW2 = 1 / m * dZ2.dot(A1.T)
    db2 = 1 / m * np.sum(dZ2)
    dZ1 = W2.T.dot(dZ2) * ReLU_deriv(Z1)
    dW1 = 1 / m * dZ1.dot(X.T)
    db1 = 1 / m * np.sum(dZ1)
    #print(m)
    return dW1, db1, dW2, db2

def update_params(W1, b1, W2, b2, dW1, db1, dW2, db2, alpha):
    W1 = W1 - alpha * dW1
    b1 = b1 - alpha * db1    
    W2 = W2 - alpha * dW2  
    b2 = b2 - alpha * db2    
    return W1, b1, W2, b2

# %%
    W1 = np.random.rand(250, 250) - 0.5
    b1 = np.random.rand(250, 1) - 0.5
    W2 = np.random.rand(250, 250) - 0.5
    b2 = np.random.rand(250, 1) - 0.5

# %%
def get_predictions(A2):
    return np.argmax(A2, 0)

def get_accuracy(predictions, Y):
    #print(predictions, Y)
    return np.sum(predictions == Y) / Y.size

def gradient_descent(X, Y, alpha, iterations):
    W1, b1, W2, b2 = init_params()
    #print(W1.shape)
    for i in range(iterations):
        Z1, A1, Z2, A2 = forward_prop(W1, b1, W2, b2, X)
        dW1, db1, dW2, db2 = backward_prop(Z1, A1, Z2, A2, W1, W2, X, Y)
        W1, b1, W2, b2 = update_params(W1, b1, W2, b2, dW1, db1, dW2, db2, alpha)
        if i % 10 == 0:
            print("Iteration: ", i)
            predictions = get_predictions(A2)
            print(get_accuracy(predictions, Y))
    return W1, b1, W2, b2

# %%
W1, b1, W2, b2 = gradient_descent(X_train, Y_train, 0.05, 50)
print(W1, b1, W2, b2)
# Out:
# Iteration:  0
# 0.4166666666666667
# Iteration:  10
# 23.0
# Iteration:  20
# 23.0
# Iteration:  30
# 23.0
# Iteration:  40
# 23.0
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]] [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
# ...
