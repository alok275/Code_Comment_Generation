# %%
import nltk

# %%
fname='C:/Users/ostina/Documents/ES/fianl/funcom_processed/dump/comment.csv'

# %%
with open(fname,'r')as myfile:
          data=myfile.read().replace('\n','')

# %%
data2=data.replace("/","")
#print(data2)

# %%
for i,line in enumerate(data2.split('\n')):
    if i>10:
        break
    #print(str(i)+":"+'\t'+line)

# %%
from nltk import sent_tokenize,word_tokenize

# %%
sent_tokenize(data2)
# Out:
# ['Comment[# Extended Euclid][# Uses ExtendedEuclid to find inverses][# This function find the inverses of a i.e., a^(-1)][# Same a above using InvertingModulo][# add function][# add function][# add function][# equal to the length of original text][# generated with the help of the key][# and returns the original text][# Current minimum recommendation is 2048 bit (group 14)][# and it seems to run nicely!',
#  '][# query with O(lg n)][# returns lca of node u,v][# runs a breadth first search from root node of the tree][# this is min-heapify method][# Used to change the data of a particular node][# adding nodes][# swapping nodes][# A utility function to print elements of array][# for calculating u value][# function is the f(x) and derivative is the"f(x)"][# Test: convert_to_negative()][# Test: change_contrast()][# canny.gen_gaussian_kernel()][# canny.py][# filtersgaussian_filter.py][# returns (F(n), F(n-1))][# Print order of matrix with Ai as Matrix][# Random population created now"its"time to evaluate][# Select, Crossover and Mutate a new population][# Finding Articulation Points in Undirected Graph][# function to search the path][# find the isolated node in the graph][# vertices of same set.',
#  '][# vertices of same set.',
#  '][# for printing the Graph vertices][# for adding the edge between two vertices][# Based on Min Heap][# This is a sample depth first search to be used at max_flow][# Here we calculate the flow that reaches the sink][# handles repetition][# handles if the input does not exist][# if no destination is meant the default value is -1][# the count will be random from 10 to 10000][# handles repetition][# handles if the input does not exist][# if no destination is meant the default value is -1][# the count will be random from 10 to 10000][# make only one source and one sink][# You should override it][# using dfs for finding eulerian path traversal][# for checking in graph has euler path or circuit][# Finding Bridges in Undirected Graph][# Finding longest distance in Directed Acyclic Graph using KahnsAlgorithm][# Disjoint Set Node to store the parent and rank][# Disjoint Set DataStructure][# Update function if value of any node in min-heap decreases][# PRNG (Xorshift by George Marsaglia)][# Functions of binary conversion--------------------------------------][# Functions of hamming code-------------------------------------------][# @staticmethod][# Make a training dataset drawn from a gaussian distribution][# Make corresponding Y flags to detecting classes][# Calculate the class means][# Calculate the class probabilities][# Calculate the variance][# Making predictions][# Calculating Accuracy][# Main Function][# here alpha is the learning rate, X is the feature matrix,y is the target matrix][# Visualizing the Polymonial Regression results][# Mean Absolute Error][# Mean Squared Error][# Root Mean Squared Error][# Root Mean Square Logarithmic Error][# Mean Bias Deviation][# Calculate alphas using SMO algorithm][# Predict test samles][# Check if alpha violate KKT condition][# Get value calculated from kernel function][# Get"samples"error][# Calculate Kernel matrix of all possible i1,i2 ,saving time][# Predict test"samples"tag][# Choose alpha1 and alpha2][# Get the new alpha2 and new alpha1][# Normalise data using min_max way][# different functions implementing different types of"SVMs"][# Eulers Totient function finds the number of relative primes of a number n from 1 to n][# Divide and Conquer algorithm][# Divide and Conquer algorithm][# Return true if 2^p - 1 is prime][# if"its"not a prime, the chance of it returning true is at most 14**prec][# A local function to see if a dot lands in the circle.',
#  '][# Discrete fourier transform of A and B][# multiply the DFTs of A and B and find A*B][# Overwrite __str__ for print(); Shows A, B and A*B][# DarkCoder][class matrix: # Public class to implement a graph][# MATRIX INFORMATION][# MATRIX MANIPULATION][# MATRIX OPERATIONS][# Make string and return][# Function to print upper half of diamond (pyramid)][# Function to print lower half of diamond (pyramid)][# Function to print complete diamond pattern of "*"][# i= how many letters or characters the password length will be][# Function called at each step of the animation][# This function is not part of the problem, I did it just for fun][# the builtin functions.',
#  '][# small helper function for modular exponentiation][# iteration version][# iteration over the unsorted list][# creates a reverse sorted list and sorts it][# BST data structure][# Emission in the last half hour][# Emissions in a specific date range][# Get main domain name (example.com)][# Get sub domain name (sub.example.com)]']

# %%
for sent in sent_tokenize(data2):
    print(word_tokenize(sent))
# Out:
# ['Comment', '[', '#', 'Extended', 'Euclid', ']', '[', '#', 'Uses', 'ExtendedEuclid', 'to', 'find', 'inverses', ']', '[', '#', 'This', 'function', 'find', 'the', 'inverses', 'of', 'a', 'i.e.', ',', 'a^', '(', '-1', ')', ']', '[', '#', 'Same', 'a', 'above', 'using', 'InvertingModulo', ']', '[', '#', 'add', 'function', ']', '[', '#', 'add', 'function', ']', '[', '#', 'add', 'function', ']', '[', '#', 'equal', 'to', 'the', 'length', 'of', 'original', 'text', ']', '[', '#', 'generated', 'with', 'the', 'help', 'of', 'the', 'key', ']', '[', '#', 'and', 'returns', 'the', 'original', 'text', ']', '[', '#', 'Current', 'minimum', 'recommendation', 'is', '2048', 'bit', '(', 'group', '14', ')', ']', '[', '#', 'and', 'it', 'seems', 'to', 'run', 'nicely', '!']
# [']', '[', '#', 'query', 'with', 'O', '(', 'lg', 'n', ')', ']', '[', '#', 'returns', 'lca', 'of', 'node', 'u', ',', 'v', ']', '[', '#', 'runs', 'a', 'breadth', 'first', 'search', 'from', 'root', 'node', 'of', 'the', 'tree', ']', '[', '#', 'this', 'is', 'min-heapify', 'method', ']', '[', '#', 'Used', 'to', 'change', 'the', 'data', 'of', 'a', 'particular', 'node', ']', '[', '#', 'adding', 'nodes', ']', '[', '#', 'swapping', 'nodes', ']', '[', '#', 'A', 'utility', 'function', 'to', 'print', 'elements', 'of', 'array', ']', '[', '#', 'for', 'calculating', 'u', 'value', ']', '[', '#', 'function', 'is', 'the', 'f', '(', 'x', ')', 'and', 'derivative', 'is', 'the', "''", 'f', '(', 'x', ')', "''", ']', '[', '#', 'Test', ':', 'convert_to_negative', '(', ')', ']', '[', '#', 'Test', ':', 'change_contrast', '(', ')', ']', '[', '#', 'canny.gen_gaussian_kernel', '(', ')', ']', '[', '#', 'canny.py', ']', '[', '#', 'filtersgaussian_filter.py', ']', '[', '#', 'returns', '(', 'F', '(', 'n', ')', ',', 'F', '(', 'n-1', ')', ')', ']', '[', '#', 'Print', 'order', 'of', 'matrix', 'with', 'Ai', 'as', 'Matrix', ']', '[', '#', 'Random', 'population', 'created', 'now', "''", 'its', "''", 'time', 'to', 'evaluate', ']', '[', '#', 'Select', ',', 'Crossover', 'and', 'Mutate', 'a', 'new', 'population', ']', '[', '#', 'Finding', 'Articulation', 'Points', 'in', 'Undirected', 'Graph', ']', '[', '#', 'function', 'to', 'search', 'the', 'path', ']', '[', '#', 'find', 'the', 'isolated', 'node', 'in', 'the', 'graph', ']', '[', '#', 'vertices', 'of', 'same', 'set', '.']
# [']', '[', '#', 'vertices', 'of', 'same', 'set', '.']
# [']', '[', '#', 'for', 'printing', 'the', 'Graph', 'vertices', ']', '[', '#', 'for', 'adding', 'the', 'edge', 'between', 'two', 'vertices', ']', '[', '#', 'Based', 'on', 'Min', 'Heap', ']', '[', '#', 'This', 'is', 'a', 'sample', 'depth', 'first', 'search', 'to', 'be', 'used', 'at', 'max_flow', ']', '[', '#', 'Here', 'we', 'calculate', 'the', 'flow', 'that', 'reaches', 'the', 'sink', ']', '[', '#', 'handles', 'repetition', ']', '[', '#', 'handles', 'if', 'the', 'input', 'does', 'not', 'exist', ']', '[', '#', 'if', 'no', 'destination', 'is', 'meant', 'the', 'default', 'value', 'is', '-1', ']', '[', '#', 'the', 'count', 'will', 'be', 'random', 'from', '10', 'to', '10000', ']', '[', '#', 'handles', 'repetition', ']', '[', '#', 'handles', 'if', 'the', 'input', 'does', 'not', 'exist', ']', '[', '#', 'if', 'no', 'destination', 'is', 'meant', 'the', 'default', 'value', 'is', '-1', ']', '[', '#', 'the', 'count', 'will', 'be', 'random', 'from', '10', 'to', '10000', ']', '[', '#', 'make', 'only', 'one', 'source', 'and', 'one', 'sink', ']', '[', '#', 'You', 'should', 'override', 'it', ']', '[', '#', 'using', 'dfs', 'for', 'finding', 'eulerian', 'path', 'traversal', ']', '[', '#', 'for', 'checking', 'in', 'graph', 'has', 'euler', 'path', 'or', 'circuit', ']', '[', '#', 'Finding', 'Bridges', 'in', 'Undirected', 'Graph', ']', '[', '#', 'Finding', 'longest', 'distance', 'in', 'Directed', 'Acyclic', 'Graph', 'using', 'KahnsAlgorithm', ']', '[', '#', 'Disjoint', 'Set', 'Node', 'to', 'store', 'the', 'parent', 'and', 'rank', ']', '[', '#', 'Disjoint', 'Set', 'DataStructure', ']', '[', '#', 'Update', 'function', 'if', 'value', 'of', 'any', 'node', 'in', 'min-heap', 'decreases', ']', '[', '#', 'PRNG', '(', 'Xorshift', 'by', 'George', 'Marsaglia', ')', ']', '[', '#', 'Functions', 'of', 'binary', 'conversion', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', ']', '[', '#', 'Functions', 'of', 'hamming', 'code', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '-', ']', '[', '#', '@', 'staticmethod', ']', '[', '#', 'Make', 'a', 'training', 'dataset', 'drawn', 'from', 'a', 'gaussian', 'distribution', ']', '[', '#', 'Make', 'corresponding', 'Y', 'flags', 'to', 'detecting', 'classes', ']', '[', '#', 'Calculate', 'the', 'class', 'means', ']', '[', '#', 'Calculate', 'the', 'class', 'probabilities', ']', '[', '#', 'Calculate', 'the', 'variance', ']', '[', '#', 'Making', 'predictions', ']', '[', '#', 'Calculating', 'Accuracy', ']', '[', '#', 'Main', 'Function', ']', '[', '#', 'here', 'alpha', 'is', 'the', 'learning', 'rate', ',', 'X', 'is', 'the', 'feature', 'matrix', ',', 'y', 'is', 'the', 'target', 'matrix', ']', '[', '#', 'Visualizing', 'the', 'Polymonial', 'Regression', 'results', ']', '[', '#', 'Mean', 'Absolute', 'Error', ']', '[', '#', 'Mean', 'Squared', 'Error', ']', '[', '#', 'Root', 'Mean', 'Squared', 'Error', ']', '[', '#', 'Root', 'Mean', 'Square', 'Logarithmic', 'Error', ']', '[', '#', 'Mean', 'Bias', 'Deviation', ']', '[', '#', 'Calculate', 'alphas', 'using', 'SMO', 'algorithm', ']', '[', '#', 'Predict', 'test', 'samles', ']', '[', '#', 'Check', 'if', 'alpha', 'violate', 'KKT', 'condition', ']', '[', '#', 'Get', 'value', 'calculated', 'from', 'kernel', 'function', ']', '[', '#', 'Get', "''", 'samples', "''", 'error', ']', '[', '#', 'Calculate', 'Kernel', 'matrix', 'of', 'all', 'possible', 'i1', ',', 'i2', ',', 'saving', 'time', ']', '[', '#', 'Predict', 'test', "''", 'samples', "''", 'tag', ']', '[', '#', 'Choose', 'alpha1', 'and', 'alpha2', ']', '[', '#', 'Get', 'the', 'new', 'alpha2', 'and', 'new', 'alpha1', ']', '[', '#', 'Normalise', 'data', 'using', 'min_max', 'way', ']', '[', '#', 'different', 'functions', 'implementing', 'different', 'types', 'of', "''", 'SVMs', "''", ']', '[', '#', 'Eulers', 'Totient', 'function', 'finds', 'the', 'number', 'of', 'relative', 'primes', 'of', 'a', 'number', 'n', 'from ...
# [']', '[', '#', 'Discrete', 'fourier', 'transform', 'of', 'A', 'and', 'B', ']', '[', '#', 'multiply', 'the', 'DFTs', 'of', 'A', 'and', 'B', 'and', 'find', 'A', '*', 'B', ']', '[', '#', 'Overwrite', '__str__', 'for', 'print', '(', ')', ';', 'Shows', 'A', ',', 'B', 'and', 'A', '*', 'B', ']', '[', '#', 'DarkCoder', ']', '[', 'class', 'matrix', ':', '#', 'Public', 'class', 'to', 'implement', 'a', 'graph', ']', '[', '#', 'MATRIX', 'INFORMATION', ']', '[', '#', 'MATRIX', 'MANIPULATION', ']', '[', '#', 'MATRIX', 'OPERATIONS', ']', '[', '#', 'Make', 'string', 'and', 'return', ']', '[', '#', 'Function', 'to', 'print', 'upper', 'half', 'of', 'diamond', '(', 'pyramid', ')', ']', '[', '#', 'Function', 'to', 'print', 'lower', 'half', 'of', 'diamond', '(', 'pyramid', ')', ']', '[', '#', 'Function', 'to', 'print', 'complete', 'diamond', 'pattern', 'of', '``', '*', "''", ']', '[', '#', 'i=', 'how', 'many', 'letters', 'or', 'characters', 'the', 'password', 'length', 'will', 'be', ']', '[', '#', 'Function', 'called', 'at', 'each', 'step', 'of', 'the', 'animation', ']', '[', '#', 'This', 'function', 'is', 'not', 'part', 'of', 'the', 'problem', ',', 'I', 'did', 'it', 'just', 'for', 'fun', ']', '[', '#', 'the', 'builtin', 'functions', '.']
# [']', '[', '#', 'small', 'helper', 'function', 'for', 'modular', 'exponentiation', ']', '[', '#', 'iteration', 'version', ']', '[', '#', 'iteration', 'over', 'the', 'unsorted', 'list', ']', '[', '#', 'creates', 'a', 'reverse', 'sorted', 'list', 'and', 'sorts', 'it', ']', '[', '#', 'BST', 'data', 'structure', ']', '[', '#', 'Emission', 'in', 'the', 'last', 'half', 'hour', ']', '[', '#', 'Emissions', 'in', 'a', 'specific', 'date', 'range', ']', '[', '#', 'Get', 'main', 'domain', 'name', '(', 'example.com', ')', ']', '[', '#', 'Get', 'sub', 'domain', 'name', '(', 'sub.example.com', ')', ']']

# %%
from nltk.corpus import stopwords
stopwords_en=stopwords.words('english')

# %%
single_tokenized_lowered = list(map(str.lower,word_tokenize(data2)))
print(single_tokenized_lowered)
# Out:
# ['comment', '[', '#', 'extended', 'euclid', ']', '[', '#', 'uses', 'extendedeuclid', 'to', 'find', 'inverses', ']', '[', '#', 'this', 'function', 'find', 'the', 'inverses', 'of', 'a', 'i.e.', ',', 'a^', '(', '-1', ')', ']', '[', '#', 'same', 'a', 'above', 'using', 'invertingmodulo', ']', '[', '#', 'add', 'function', ']', '[', '#', 'add', 'function', ']', '[', '#', 'add', 'function', ']', '[', '#', 'equal', 'to', 'the', 'length', 'of', 'original', 'text', ']', '[', '#', 'generated', 'with', 'the', 'help', 'of', 'the', 'key', ']', '[', '#', 'and', 'returns', 'the', 'original', 'text', ']', '[', '#', 'current', 'minimum', 'recommendation', 'is', '2048', 'bit', '(', 'group', '14', ')', ']', '[', '#', 'and', 'it', 'seems', 'to', 'run', 'nicely', '!', ']', '[', '#', 'query', 'with', 'o', '(', 'lg', 'n', ')', ']', '[', '#', 'returns', 'lca', 'of', 'node', 'u', ',', 'v', ']', '[', '#', 'runs', 'a', 'breadth', 'first', 'search', 'from', 'root', 'node', 'of', 'the', 'tree', ']', '[', '#', 'this', 'is', 'min-heapify', 'method', ']', '[', '#', 'used', 'to', 'change', 'the', 'data', 'of', 'a', 'particular', 'node', ']', '[', '#', 'adding', 'nodes', ']', '[', '#', 'swapping', 'nodes', ']', '[', '#', 'a', 'utility', 'function', 'to', 'print', 'elements', 'of', 'array', ']', '[', '#', 'for', 'calculating', 'u', 'value', ']', '[', '#', 'function', 'is', 'the', 'f', '(', 'x', ')', 'and', 'derivative', 'is', 'the', "''", 'f', '(', 'x', ')', "''", ']', '[', '#', 'test', ':', 'convert_to_negative', '(', ')', ']', '[', '#', 'test', ':', 'change_contrast', '(', ')', ']', '[', '#', 'canny.gen_gaussian_kernel', '(', ')', ']', '[', '#', 'canny.py', ']', '[', '#', 'filtersgaussian_filter.py', ']', '[', '#', 'returns', '(', 'f', '(', 'n', ')', ',', 'f', '(', 'n-1', ')', ')', ']', '[', '#', 'print', 'order', 'of', 'matrix', 'with', 'ai', 'as', 'matrix', ']', '[', '#', 'random', 'population', 'created', 'now', "''", 'its', "''", 'time', 'to', 'evaluate', ']', '[', '#', 'select', ',', 'crossover', 'and', 'mutate', 'a', 'new', 'population', ']', '[', '#', 'finding', 'articulation', 'points', 'in', 'undirected', 'graph', ']', '[', '#', 'function', 'to', 'search', 'the', 'path', ']', '[', '#', 'find', 'the', 'isolated', 'node', 'in', 'the', 'graph', ']', '[', '#', 'vertices', 'of', 'same', 'set', '.', ']', '[', '#', 'vertices', 'of', 'same', 'set', '.', ']', '[', '#', 'for', 'printing', 'the', 'graph', 'vertices', ']', '[', '#', 'for', 'adding', 'the', 'edge', 'between', 'two', 'vertices', ']', '[', '#', 'based', 'on', 'min', 'heap', ']', '[', '#', 'this', 'is', 'a', 'sample', 'depth', 'first', 'search', 'to', 'be', 'used', 'at', 'max_flow', ']', '[', '#', 'here', 'we', 'calculate', 'the', 'flow', 'that', 'reaches', 'the', 'sink', ']', '[', '#', 'handles', 'repetition', ']', '[', '#', 'handles', 'if', 'the', 'input', 'does', 'not', 'exist', ']', '[', '#', 'if', 'no', 'destination', 'is', 'meant', 'the', 'default', 'value', 'is', '-1', ']', '[', '#', 'the', 'count', 'will', 'be', 'random', 'from', '10', 'to', '10000', ']', '[', '#', 'handles', 'repetition', ']', '[', '#', 'handles', 'if', 'the', 'input', 'does', 'not', 'exist', ']', '[', '#', 'if', 'no', 'destination', 'is', 'meant', 'the', 'default', 'value', 'is', '-1', ']', '[', '#', 'the', 'count', 'will', 'be', 'random', 'from', '10', 'to', '10000', ']', '[', '#', 'make', 'only', 'one', 'source', 'and', 'one', 'sink', ']', '[', '#', 'you', 'should', 'override', 'it', ']', '[', '#', 'using', 'dfs', 'for', 'finding', 'eulerian', 'path', 'traversal', ']', '[', '#', 'for', 'checking', 'in', 'graph', 'has', 'euler', 'path', 'or', 'circuit', ']', '[', '#', 'finding', 'bridges', 'in', 'undirected', 'graph', ']', '[', '#', 'finding', 'longest', 'distance', 'in', 'directed', 'acyclic', 'graph', 'using', 'kahnsalgorithm', ']', '[', '#', 'disjoint', 'set', 'node', 'to', 'store', 'the', 'parent', 'and', 'rank', ']', '[', '#', 'disjoint', 'set', 'datastructure', ']', '[', '#', 'update', 'function', 'if', 'value', 'of', ...

# %%
# remove stopwords
stopwords_en=set(stopwords.words('english'))
print([word for word in single_tokenized_lowered if word not in stopwords_en])
# Out:
# ['comment', '[', '#', 'extended', 'euclid', ']', '[', '#', 'uses', 'extendedeuclid', 'find', 'inverses', ']', '[', '#', 'function', 'find', 'inverses', 'i.e.', ',', 'a^', '(', '-1', ')', ']', '[', '#', 'using', 'invertingmodulo', ']', '[', '#', 'add', 'function', ']', '[', '#', 'add', 'function', ']', '[', '#', 'add', 'function', ']', '[', '#', 'equal', 'length', 'original', 'text', ']', '[', '#', 'generated', 'help', 'key', ']', '[', '#', 'returns', 'original', 'text', ']', '[', '#', 'current', 'minimum', 'recommendation', '2048', 'bit', '(', 'group', '14', ')', ']', '[', '#', 'seems', 'run', 'nicely', '!', ']', '[', '#', 'query', '(', 'lg', 'n', ')', ']', '[', '#', 'returns', 'lca', 'node', 'u', ',', 'v', ']', '[', '#', 'runs', 'breadth', 'first', 'search', 'root', 'node', 'tree', ']', '[', '#', 'min-heapify', 'method', ']', '[', '#', 'used', 'change', 'data', 'particular', 'node', ']', '[', '#', 'adding', 'nodes', ']', '[', '#', 'swapping', 'nodes', ']', '[', '#', 'utility', 'function', 'print', 'elements', 'array', ']', '[', '#', 'calculating', 'u', 'value', ']', '[', '#', 'function', 'f', '(', 'x', ')', 'derivative', "''", 'f', '(', 'x', ')', "''", ']', '[', '#', 'test', ':', 'convert_to_negative', '(', ')', ']', '[', '#', 'test', ':', 'change_contrast', '(', ')', ']', '[', '#', 'canny.gen_gaussian_kernel', '(', ')', ']', '[', '#', 'canny.py', ']', '[', '#', 'filtersgaussian_filter.py', ']', '[', '#', 'returns', '(', 'f', '(', 'n', ')', ',', 'f', '(', 'n-1', ')', ')', ']', '[', '#', 'print', 'order', 'matrix', 'ai', 'matrix', ']', '[', '#', 'random', 'population', 'created', "''", "''", 'time', 'evaluate', ']', '[', '#', 'select', ',', 'crossover', 'mutate', 'new', 'population', ']', '[', '#', 'finding', 'articulation', 'points', 'undirected', 'graph', ']', '[', '#', 'function', 'search', 'path', ']', '[', '#', 'find', 'isolated', 'node', 'graph', ']', '[', '#', 'vertices', 'set', '.', ']', '[', '#', 'vertices', 'set', '.', ']', '[', '#', 'printing', 'graph', 'vertices', ']', '[', '#', 'adding', 'edge', 'two', 'vertices', ']', '[', '#', 'based', 'min', 'heap', ']', '[', '#', 'sample', 'depth', 'first', 'search', 'used', 'max_flow', ']', '[', '#', 'calculate', 'flow', 'reaches', 'sink', ']', '[', '#', 'handles', 'repetition', ']', '[', '#', 'handles', 'input', 'exist', ']', '[', '#', 'destination', 'meant', 'default', 'value', '-1', ']', '[', '#', 'count', 'random', '10', '10000', ']', '[', '#', 'handles', 'repetition', ']', '[', '#', 'handles', 'input', 'exist', ']', '[', '#', 'destination', 'meant', 'default', 'value', '-1', ']', '[', '#', 'count', 'random', '10', '10000', ']', '[', '#', 'make', 'one', 'source', 'one', 'sink', ']', '[', '#', 'override', ']', '[', '#', 'using', 'dfs', 'finding', 'eulerian', 'path', 'traversal', ']', '[', '#', 'checking', 'graph', 'euler', 'path', 'circuit', ']', '[', '#', 'finding', 'bridges', 'undirected', 'graph', ']', '[', '#', 'finding', 'longest', 'distance', 'directed', 'acyclic', 'graph', 'using', 'kahnsalgorithm', ']', '[', '#', 'disjoint', 'set', 'node', 'store', 'parent', 'rank', ']', '[', '#', 'disjoint', 'set', 'datastructure', ']', '[', '#', 'update', 'function', 'value', 'node', 'min-heap', 'decreases', ']', '[', '#', 'prng', '(', 'xorshift', 'george', 'marsaglia', ')', ']', '[', '#', 'functions', 'binary', 'conversion', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', ']', '[', '#', 'functions', 'hamming', 'code', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '-', ']', '[', '#', '@', 'staticmethod', ']', '[', '#', 'make', 'training', 'dataset', 'drawn', 'gaussian', 'distribution', ']', '[', '#', 'make', 'corresponding', 'flags', 'detecting', 'classes', ']', '[', '#', 'calculate', 'class', 'means', ']', '[', '#', 'calculate', 'class', 'probabilities', ']', '[', '#', 'calculate', 'variance', ']', '[', '#', 'making', 'predictions', '] ...

# %%
from string import punctuation
print('from string.punctuation:',type(punctuation),punctuation)
# Out:
# from string.punctuation: <class 'str'> !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
# remove punctuation
stopwords_en_withpunct=stopwords_en.union(set(punctuation))
print(stopwords_en_withpunct)
# Out:
# {'how', 'doing', 't', 'off', "aren't", '-', 'your', '>', '/', 'itself', 'own', 'was', 'once', 'some', 'didn', "'", "that'll", 'of', 'you', "don't", 'hadn', '|', 'myself', 'until', 'any', 'its', 'through', 'couldn', 'i', 'hers', 'to', 'do', 'who', 'few', 'it', 'as', 'will', 'or', 'at', 'here', '#', 'ma', ',', 'out', 'are', 'isn', 'more', 'such', 'has', 'again', "should've", "isn't", 'then', 'from', "it's", 'no', 'y', '$', 'his', '^', '}', "doesn't", 'being', '@', ']', 'ourselves', 'he', "wouldn't", "you've", 'against', "couldn't", 'shan', 'above', '<', 'which', '!', "hasn't", 'our', 're', '[', ')', 'is', "you're", 'we', 'yours', '{', 'so', 'o', 'were', 'them', 'these', 'both', 'had', 'wasn', '_', 'they', 'most', '"', "you'd", '&', "shouldn't", 'because', 'other', 'before', 've', 'and', 'won', 'those', '=', 'further', 'mightn', "wasn't", '%', ':', 'me', 'll', 'over', 'a', "hadn't", 'd', 'my', 'been', 'needn', 'himself', 'theirs', 'shouldn', '.', 'm', 'whom', 'too', 'aren', '\\', 'him', 'between', 's', "mustn't", 'if', 'what', 'her', 'than', 'ours', 'be', 'haven', 'nor', 'wouldn', '+', 'by', 'themselves', 'after', 'for', 'ain', ';', 'mustn', 'where', "needn't", 'now', 'only', 'she', 'each', '`', '~', 'why', 'have', 'below', "haven't", 'am', 'should', 'an', "she's", 'during', 'when', "you'll", 'doesn', 'yourself', 'not', 'very', 'same', 'just', '(', 'did', 'there', "mightn't", 'their', 'down', 'having', 'the', 'while', "weren't", 'don', 'yourselves', 'on', 'does', 'herself', 'all', "didn't", 'weren', "won't", 'under', 'hasn', 'that', "shan't", 'can', 'but', 'into', 'with', 'in', 'this', 'about', '*', 'up', '?'}

# %%
print([word for word in single_tokenized_lowered if word not in stopwords_en_withpunct])
# Out:
# ['comment', 'extended', 'euclid', 'uses', 'extendedeuclid', 'find', 'inverses', 'function', 'find', 'inverses', 'i.e.', 'a^', '-1', 'using', 'invertingmodulo', 'add', 'function', 'add', 'function', 'add', 'function', 'equal', 'length', 'original', 'text', 'generated', 'help', 'key', 'returns', 'original', 'text', 'current', 'minimum', 'recommendation', '2048', 'bit', 'group', '14', 'seems', 'run', 'nicely', 'query', 'lg', 'n', 'returns', 'lca', 'node', 'u', 'v', 'runs', 'breadth', 'first', 'search', 'root', 'node', 'tree', 'min-heapify', 'method', 'used', 'change', 'data', 'particular', 'node', 'adding', 'nodes', 'swapping', 'nodes', 'utility', 'function', 'print', 'elements', 'array', 'calculating', 'u', 'value', 'function', 'f', 'x', 'derivative', "''", 'f', 'x', "''", 'test', 'convert_to_negative', 'test', 'change_contrast', 'canny.gen_gaussian_kernel', 'canny.py', 'filtersgaussian_filter.py', 'returns', 'f', 'n', 'f', 'n-1', 'print', 'order', 'matrix', 'ai', 'matrix', 'random', 'population', 'created', "''", "''", 'time', 'evaluate', 'select', 'crossover', 'mutate', 'new', 'population', 'finding', 'articulation', 'points', 'undirected', 'graph', 'function', 'search', 'path', 'find', 'isolated', 'node', 'graph', 'vertices', 'set', 'vertices', 'set', 'printing', 'graph', 'vertices', 'adding', 'edge', 'two', 'vertices', 'based', 'min', 'heap', 'sample', 'depth', 'first', 'search', 'used', 'max_flow', 'calculate', 'flow', 'reaches', 'sink', 'handles', 'repetition', 'handles', 'input', 'exist', 'destination', 'meant', 'default', 'value', '-1', 'count', 'random', '10', '10000', 'handles', 'repetition', 'handles', 'input', 'exist', 'destination', 'meant', 'default', 'value', '-1', 'count', 'random', '10', '10000', 'make', 'one', 'source', 'one', 'sink', 'override', 'using', 'dfs', 'finding', 'eulerian', 'path', 'traversal', 'checking', 'graph', 'euler', 'path', 'circuit', 'finding', 'bridges', 'undirected', 'graph', 'finding', 'longest', 'distance', 'directed', 'acyclic', 'graph', 'using', 'kahnsalgorithm', 'disjoint', 'set', 'node', 'store', 'parent', 'rank', 'disjoint', 'set', 'datastructure', 'update', 'function', 'value', 'node', 'min-heap', 'decreases', 'prng', 'xorshift', 'george', 'marsaglia', 'functions', 'binary', 'conversion', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', 'functions', 'hamming', 'code', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', 'staticmethod', 'make', 'training', 'dataset', 'drawn', 'gaussian', 'distribution', 'make', 'corresponding', 'flags', 'detecting', 'classes', 'calculate', 'class', 'means', 'calculate', 'class', 'probabilities', 'calculate', 'variance', 'making', 'predictions', 'calculating', 'accuracy', 'main', 'function', 'alpha', 'learning', 'rate', 'x', 'feature', 'matrix', 'target', 'matrix', 'visualizing', 'polymonial', 'regression', 'results', 'mean', 'absolute', 'error', 'mean', 'squared', 'error', 'root', 'mean', 'squared', 'error', 'root', 'mean', 'square', 'logarithmic', 'error', 'mean', 'bias', 'deviation', 'calculate', 'alphas', 'using', 'smo', 'algorithm', 'predict', 'test', 'samles', 'check', 'alpha', 'violate', 'kkt', 'condition', 'get', 'value', 'calculated', 'kernel', 'function', 'get', "''", 'samples', "''", 'error', 'calculate', 'kernel', 'matrix', 'possible', 'i1', 'i2', 'saving', 'time', 'predict', 'test', "''", 'samples', "''", 'tag', 'choose', 'alpha1', 'alpha2', 'get', 'new', 'alpha2', 'new', 'alpha1', 'normalise', 'data', 'using', 'min_max', 'way', 'different', 'functions', 'implementing', 'different', 'types', "''", 'svms', "''", 'eulers', 'totient', 'function', 'finds', 'number', 'relative', 'primes', 'number', 'n', '1', 'n', 'divide', 'conquer', 'algorithm', 'divide', 'conquer', 'algorithm', 'return', 'true', '2^p', '1', 'prime', "''", "''", 'prime', 'chance', 'returning', 'true', '14', 'prec', 'local', 'function', 'se ...

# %%
#Stemmer
from nltk.stem import PorterStemmer
porter=PorterStemmer()

for word in single_tokenized_lowered:
    print(porter.stem(word))
# Out:
# comment
# [
# #
# extend
# euclid
# ]
# [
# #
# use
# extendedeuclid
# to
# find
# invers
# ]
# [
# #
# thi
# function
# find
# the
# invers
# of
# a
# i.e.
# ,
# a^
# (
# -1
# )
# ]
# [
# #
# same
# a
# abov
# use
# invertingmodulo
# ]
# [
# #
# add
# function
# ]
# [
# #
# add
# function
# ]
# [
# #
# add
# function
# ]
# [
# #
# equal
# to
# the
# length
# of
# origin
# text
# ]
# [
# #
# gener
# with
# the
# help
# of
# the
# key
# ]
# [
# #
# and
# return
# the
# origin
# text
# ]
# [
# #
# current
# minimum
# recommend
# is
# 2048
# bit
# (
# group
# 14
# )
# ]
# [
# #
# and
# it
# seem
# to
# run
# nice
# !
# ]
# [
# #
# queri
# with
# o
# (
# lg
# n
# )
# ]
# [
# #
# return
# lca
# of
# node
# u
# ,
# v
# ]
# [
# #
# run
# a
# breadth
# first
# search
# from
# root
# node
# of
# the
# tree
# ]
# [
# #
# thi
# is
# min-heapifi
# method
# ]
# [
# #
# use
# to
# chang
# the
# data
# of
# a
# particular
# node
# ]
# [
# #
# ad
# node
# ]
# [
# #
# swap
# node
# ]
# [
# #
# a
# util
# function
# to
# print
# element
# of
# array
# ]
# [
# #
# for
# calcul
# u
# valu
# ]
# [
# #
# function
# is
# the
# f
# (
# x
# )
# and
# deriv
# is
# the
# ''
# f
# (
# x
# )
# ''
# ]
# [
# #
# test
# :
# convert_to_neg
# (
# )
# ]
# [
# #
# test
# :
# change_contrast
# (
# )
# ]
# [
# #
# canny.gen_gaussian_kernel
# (
# )
# ]
# [
# #
# canny.pi
# ]
# [
# #
# filtersgaussian_filter.pi
# ]
# [
# #
# return
# (
# f
# (
# n
# )
# ,
# f
# (
# n-1
# )
# )
# ]
# [
# #
# print
# order
# of
# matrix
# with
# ai
# as
# matrix
# ]
# [
# #
# random
# popul
# creat
# now
# ''
# it
# ''
# time
# to
# evalu
# ]
# [
# #
# select
# ,
# crossov
# and
# mutat
# a
# new
# popul
# ]
# [
# #
# find
# articul
# point
# in
# undirect
# graph
# ]
# [
# #
# function
# to
# search
# the
# path
# ]
# [
# #
# find
# the
# isol
# node
# in
# the
# graph
# ]
# [
# #
# vertic
# of
# same
# set
# .
# ]
# [
# #
# vertic
# of
# same
# set
# .
# ]
# [
# #
# for
# print
# the
# graph
# vertic
# ]
# [
# #
# for
# ad
# the
# edg
# between
# two
# vertic
# ]
# [
# #
# base
# on
# min
# heap
# ]
# [
# #
# thi
# is
# a
# sampl
# depth
# first
# search
# to
# be
# use
# at
# max_flow
# ]
# [
# #
# here
# we
# calcul
# the
# flow
# that
# reach
# the
# sink
# ]
# [
# #
# handl
# repetit
# ]
# [
# #
# handl
# if
# the
# input
# doe
# not
# exist
# ]
# [
# #
# if
# no
# destin
# is
# meant
# the
# default
# valu
# is
# -1
# ]
# [
# #
# the
# count
# will
# be
# random
# from
# 10
# to
# 10000
# ]
# [
# #
# handl
# repetit
# ]
# [
# #
# handl
# if
# the
# input
# doe
# not
# exist
# ]
# [
# #
# if
# no
# destin
# is
# meant
# the
# default
# valu
# is
# -1
# ]
# [
# #
# the
# count
# will
# be
# random
# from
# 10
# to
# 10000
# ]
# [
# #
# make
# onli
# one
# sourc
# and
# one
# sink
# ]
# [
# #
# you
# should
# overrid
# it
# ]
# [
# #
# use
# df
# for
# find
# eulerian
# path
# travers
# ]
# [
# #
# for
# check
# in
# graph
# ha
# euler
# path
# or
# circuit
# ]
# [
# #
# find
# bridg
# in
# undirect
# graph
# ]
# [
# #
# find
# longest
# distanc
# in
# direct
# acycl
# graph
# use
# kahnsalgorithm
# ]
# [
# #
# disjoint
# set
# node
# to
# store
# the
# parent
# and
# rank
# ]
# [
# #
# disjoint
# set
# datastructur
# ]
# [
# #
# updat
# function
# if
# valu
# of
# ani
# node
# in
# min-heap
# decreas
# ]
# [
# #
# prng
# (
# xorshift
# by
# georg
# marsaglia
# )
# ]
# [
# #
# function
# of
# binari
# convers
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# ]
# [
# #
# function
# of
# ham
# code
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# -
# ]
# [
# #
# @
# staticmethod
# ]
# [
# #
# make
# a
# train
# dataset
# drawn
# from
# a
# gaussian
# distribut
# ]
# [
# #
# make
# correspond
# y
# flag
# to
# detect
# class
# ]
# [
# #
# calcul
# the
# class
# mean
# ]
# [
# #
# calcul
# the
# class
# probabl
# ]
# [
# #
# calcul
# the
# varianc
# ]
# [
# #
# make
# predict
# ]
# [
# #
# calcul
# accuraci
# ]
# [
# #
# main
# function
# ]
# [
# #
# here
# alpha
# is
# the
# learn
# rate
# ,
# x
# is
# the
# featur
# matrix
# ,
# y
# is
# the
# target
# matrix
# ]
# [
# #
# visual
# the
# polymoni
# regress
# result
# ]
# [
# #
# mean
# absolut
# error
# ]
# [
# #
# mean
# squar
# error
# ]
# [
# #
# root
# mean
# squar
# error
# ]
# [
# #
# root
# mean
# squar
# logarithm
# error
# ]
# [
# #
# mean
# bia
# deviat
# ]
# [
# #
# calcul
# alpha
# use
# smo
# algorithm
# ]
# [
# #
# predict
# test
# saml
# ]
# [
# #
# check
# if
# alpha
# violat
# kkt
# condit
# ]
# [
# #
# get
# valu
# calcul
# from
# kernel
# function
# ]
# [
# #
# get
# ''
# sampl
# ''
# error
# ]
# [
# #
# calcul
# kernel
# matrix
# of
# all
# possibl
# i1
# ,
# i2
# ,
# save
# time
# ]
# [
# #
# predict
# test
# ''
# sampl
# ''
# tag
# ]
# [
# #
# choos
# alpha1
# and
# alpha2
# ]
# [
# #
# get
# the
# new
# alpha2
# and
# new
# alpha1
# ]
# [
# #
# normalis
# data
# use
# min_max
# way
# ]
# [
# #
# differ
# function
# implement
# differ
# type
# of
# ''
# svm
# ''
# ]
# [
# #
# euler
# totient
# function
# find
# the
# number
# of
# rel
# prime
# of
# a
# number
# n
# from
# 1
# to
# n
# ]
# [
# #
# divid
# and
# conquer
# algorithm
# ]
# [
# #
# divid
# and
# conquer
# algorithm
# ]
# [
# #
# return
# true
# if
# 2^p
# -
# 1
# is
# prime
# ]
# [
# #
# if
# ''
# it
# ''
# not
# a
# prime
# ,
# the
# chanc
# of
# it
# return
# true
# is
# at
# most
# 14
# *
# *
# prec
# ]
# [
# #
# a
# local
# function
# to
# see
# if
# a
# dot
# land
# in
# the
# circl
# .
# ]
# [
# #
# discret
# fourier
# transform
# of
# a
# and
# b
# ]
# [
# #
# multipli
# the
# dft
# of
# a
# and
# b
# and
# find
# a
# *
# b
# ]
# [
# #
# overwrit
# __str__
# for
# print
# (
# )
# ;
# show
# a
# ,
# b
# and
# a
# *
# b
# ]
# [
# #
# darkcod
# ]
# [
# class
# matrix
# :
# #
# public
# class
# to
# implement
# a
# graph
# ]
# [
# #
# matrix
# inform
# ]
# [
# #
# matrix
# manipul
# ]
# [
# #
# matrix
# oper
# ]
# [
# #
# make
# string
# and
# return
# ]
# [
# #
# function
# to
# print
# upper
# half
# of
# diamond
# (
# pyramid
# )
# ]
# [
# #
# function
# to
# print
# lower
# half
# of
# diamond
# (
# pyramid
# )
# ]
# [
# #
# function
# to
# print
# complet
# diamond
# pattern
# of
# ``
# *
# ''
# ]
# [
# #
# i=
# how
# mani
# letter
# or
# charact
# the
# password
# length
# will
# be
# ]
# [
# #
# function
# call
# at
# each
# step
# of
# the
# anim
# ]
# [
# #
# thi
# function
# is
# not
# part
# of
# the
# problem
# ,
# i
# did
# it
# just
# for
# fun
# ]
# [
# #
# the
# builtin
# function
# .
# ]
# [
# #
# small
# helper
# function
# for
# modular
# exponenti
# ]
# [
# #
# iter
# version
# ]
# [
# #
# iter
# over
# the
# unsort
# list
# ]
# [
# #
# creat
# a
# revers
# sort
# list
# and
# sort
# it
# ]
# [
# #
# bst
# data
# structur
# ]
# [
# #
# emiss
# in
# the
# last
# half
# hour
# ]
# [
# #
# emiss
# in
# a
# specif
# date
# rang
# ]
# [
# #
# get
# main
# domain
# name
# (
# example.com
# )
# ]
# [
# #
# get
# sub
# domain
# name
# (
# sub.example.com
# )
# ]

# %%
from nltk.stem import WordNetLemmatizer
wnl=WordNetLemmatizer()

# %%
for word in single_tokenized_lowered:
    print(wnl.lemmatize(word))
# Out:
# comment
# [
# #
# extended
# euclid
# ]
# [
# #
# us
# extendedeuclid
# to
# find
# inverse
# ]
# [
# #
# this
# function
# find
# the
# inverse
# of
# a
# i.e.
# ,
# a^
# (
# -1
# )
# ]
# [
# #
# same
# a
# above
# using
# invertingmodulo
# ]
# [
# #
# add
# function
# ]
# [
# #
# add
# function
# ]
# [
# #
# add
# function
# ]
# [
# #
# equal
# to
# the
# length
# of
# original
# text
# ]
# [
# #
# generated
# with
# the
# help
# of
# the
# key
# ]
# [
# #
# and
# return
# the
# original
# text
# ]
# [
# #
# current
# minimum
# recommendation
# is
# 2048
# bit
# (
# group
# 14
# )
# ]
# [
# #
# and
# it
# seems
# to
# run
# nicely
# !
# ]
# [
# #
# query
# with
# o
# (
# lg
# n
# )
# ]
# [
# #
# return
# lca
# of
# node
# u
# ,
# v
# ]
# [
# #
# run
# a
# breadth
# first
# search
# from
# root
# node
# of
# the
# tree
# ]
# [
# #
# this
# is
# min-heapify
# method
# ]
# [
# #
# used
# to
# change
# the
# data
# of
# a
# particular
# node
# ]
# [
# #
# adding
# node
# ]
# [
# #
# swapping
# node
# ]
# [
# #
# a
# utility
# function
# to
# print
# element
# of
# array
# ]
# [
# #
# for
# calculating
# u
# value
# ]
# [
# #
# function
# is
# the
# f
# (
# x
# )
# and
# derivative
# is
# the
# ''
# f
# (
# x
# )
# ''
# ]
# [
# #
# test
# :
# convert_to_negative
# (
# )
# ]
# [
# #
# test
# :
# change_contrast
# (
# )
# ]
# [
# #
# canny.gen_gaussian_kernel
# (
# )
# ]
# [
# #
# canny.py
# ]
# [
# #
# filtersgaussian_filter.py
# ]
# [
# #
# return
# (
# f
# (
# n
# )
# ,
# f
# (
# n-1
# )
# )
# ]
# [
# #
# print
# order
# of
# matrix
# with
# ai
# a
# matrix
# ]
# [
# #
# random
# population
# created
# now
# ''
# it
# ''
# time
# to
# evaluate
# ]
# [
# #
# select
# ,
# crossover
# and
# mutate
# a
# new
# population
# ]
# [
# #
# finding
# articulation
# point
# in
# undirected
# graph
# ]
# [
# #
# function
# to
# search
# the
# path
# ]
# [
# #
# find
# the
# isolated
# node
# in
# the
# graph
# ]
# [
# #
# vertex
# of
# same
# set
# .
# ]
# [
# #
# vertex
# of
# same
# set
# .
# ]
# [
# #
# for
# printing
# the
# graph
# vertex
# ]
# [
# #
# for
# adding
# the
# edge
# between
# two
# vertex
# ]
# [
# #
# based
# on
# min
# heap
# ]
# [
# #
# this
# is
# a
# sample
# depth
# first
# search
# to
# be
# used
# at
# max_flow
# ]
# [
# #
# here
# we
# calculate
# the
# flow
# that
# reach
# the
# sink
# ]
# [
# #
# handle
# repetition
# ]
# [
# #
# handle
# if
# the
# input
# doe
# not
# exist
# ]
# [
# #
# if
# no
# destination
# is
# meant
# the
# default
# value
# is
# -1
# ]
# [
# #
# the
# count
# will
# be
# random
# from
# 10
# to
# 10000
# ]
# [
# #
# handle
# repetition
# ]
# [
# #
# handle
# if
# the
# input
# doe
# not
# exist
# ]
# [
# #
# if
# no
# destination
# is
# meant
# the
# default
# value
# is
# -1
# ]
# [
# #
# the
# count
# will
# be
# random
# from
# 10
# to
# 10000
# ]
# [
# #
# make
# only
# one
# source
# and
# one
# sink
# ]
# [
# #
# you
# should
# override
# it
# ]
# [
# #
# using
# dfs
# for
# finding
# eulerian
# path
# traversal
# ]
# [
# #
# for
# checking
# in
# graph
# ha
# euler
# path
# or
# circuit
# ]
# [
# #
# finding
# bridge
# in
# undirected
# graph
# ]
# [
# #
# finding
# longest
# distance
# in
# directed
# acyclic
# graph
# using
# kahnsalgorithm
# ]
# [
# #
# disjoint
# set
# node
# to
# store
# the
# parent
# and
# rank
# ]
# [
# #
# disjoint
# set
# datastructure
# ]
# [
# #
# update
# function
# if
# value
# of
# any
# node
# in
# min-heap
# decrease
# ]
# [
# #
# prng
# (
# xorshift
# by
# george
# marsaglia
# )
# ]
# [
# #
# function
# of
# binary
# conversion
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# ]
# [
# #
# function
# of
# hamming
# code
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# --
# -
# ]
# [
# #
# @
# staticmethod
# ]
# [
# #
# make
# a
# training
# dataset
# drawn
# from
# a
# gaussian
# distribution
# ]
# [
# #
# make
# corresponding
# y
# flag
# to
# detecting
# class
# ]
# [
# #
# calculate
# the
# class
# mean
# ]
# [
# #
# calculate
# the
# class
# probability
# ]
# [
# #
# calculate
# the
# variance
# ]
# [
# #
# making
# prediction
# ]
# [
# #
# calculating
# accuracy
# ]
# [
# #
# main
# function
# ]
# [
# #
# here
# alpha
# is
# the
# learning
# rate
# ,
# x
# is
# the
# feature
# matrix
# ,
# y
# is
# the
# target
# matrix
# ]
# [
# #
# visualizing
# the
# polymonial
# regression
# result
# ]
# [
# #
# mean
# absolute
# error
# ]
# [
# #
# mean
# squared
# error
# ]
# [
# #
# root
# mean
# squared
# error
# ]
# [
# #
# root
# mean
# square
# logarithmic
# error
# ]
# [
# #
# mean
# bias
# deviation
# ]
# [
# #
# calculate
# alpha
# using
# smo
# algorithm
# ]
# [
# #
# predict
# test
# samles
# ]
# [
# #
# check
# if
# alpha
# violate
# kkt
# condition
# ]
# [
# #
# get
# value
# calculated
# from
# kernel
# function
# ]
# [
# #
# get
# ''
# sample
# ''
# error
# ]
# [
# #
# calculate
# kernel
# matrix
# of
# all
# possible
# i1
# ,
# i2
# ,
# saving
# time
# ]
# [
# #
# predict
# test
# ''
# sample
# ''
# tag
# ]
# [
# #
# choose
# alpha1
# and
# alpha2
# ]
# [
# #
# get
# the
# new
# alpha2
# and
# new
# alpha1
# ]
# [
# #
# normalise
# data
# using
# min_max
# way
# ]
# [
# #
# different
# function
# implementing
# different
# type
# of
# ''
# svms
# ''
# ]
# [
# #
# euler
# totient
# function
# find
# the
# number
# of
# relative
# prime
# of
# a
# number
# n
# from
# 1
# to
# n
# ]
# [
# #
# divide
# and
# conquer
# algorithm
# ]
# [
# #
# divide
# and
# conquer
# algorithm
# ]
# [
# #
# return
# true
# if
# 2^p
# -
# 1
# is
# prime
# ]
# [
# #
# if
# ''
# it
# ''
# not
# a
# prime
# ,
# the
# chance
# of
# it
# returning
# true
# is
# at
# most
# 14
# *
# *
# prec
# ]
# [
# #
# a
# local
# function
# to
# see
# if
# a
# dot
# land
# in
# the
# circle
# .
# ]
# [
# #
# discrete
# fourier
# transform
# of
# a
# and
# b
# ]
# [
# #
# multiply
# the
# dfts
# of
# a
# and
# b
# and
# find
# a
# *
# b
# ]
# [
# #
# overwrite
# __str__
# for
# print
# (
# )
# ;
# show
# a
# ,
# b
# and
# a
# *
# b
# ]
# [
# #
# darkcoder
# ]
# [
# class
# matrix
# :
# #
# public
# class
# to
# implement
# a
# graph
# ]
# [
# #
# matrix
# information
# ]
# [
# #
# matrix
# manipulation
# ]
# [
# #
# matrix
# operation
# ]
# [
# #
# make
# string
# and
# return
# ]
# [
# #
# function
# to
# print
# upper
# half
# of
# diamond
# (
# pyramid
# )
# ]
# [
# #
# function
# to
# print
# lower
# half
# of
# diamond
# (
# pyramid
# )
# ]
# [
# #
# function
# to
# print
# complete
# diamond
# pattern
# of
# ``
# *
# ''
# ]
# [
# #
# i=
# how
# many
# letter
# or
# character
# the
# password
# length
# will
# be
# ]
# [
# #
# function
# called
# at
# each
# step
# of
# the
# animation
# ]
# [
# #
# this
# function
# is
# not
# part
# of
# the
# problem
# ,
# i
# did
# it
# just
# for
# fun
# ]
# [
# #
# the
# builtin
# function
# .
# ]
# [
# #
# small
# helper
# function
# for
# modular
# exponentiation
# ]
# [
# #
# iteration
# version
# ]
# [
# #
# iteration
# over
# the
# unsorted
# list
# ]
# [
# #
# creates
# a
# reverse
# sorted
# list
# and
# sort
# it
# ]
# [
# #
# bst
# data
# structure
# ]
# [
# #
# emission
# in
# the
# last
# half
# hour
# ]
# [
# #
# emission
# in
# a
# specific
# date
# range
# ]
# [
# #
# get
# main
# domain
# name
# (
# example.com
# )
# ]
# [
# #
# get
# sub
# domain
# name
# (
# sub.example.com
# )
# ]

# %%
stop_words=set(stopwords.words('english'))
tokenized=sent_tokenize(data2)
for i in tokenized:
    wordslist=nltk.word_tokenize(i)
    workslist=[w for w in wordslist if not w in stop_words]
    tagged = nltk.pos_tag(wordslist)
    print(tagged)
# Out:
# [('Comment', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Extended', 'NNP'), ('Euclid', 'NNP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Uses', 'VBZ'), ('ExtendedEuclid', 'NNP'), ('to', 'TO'), ('find', 'VB'), ('inverses', 'NNS'), (']', 'NNP'), ('[', 'RB'), ('#', '#'), ('This', 'DT'), ('function', 'NN'), ('find', 'VB'), ('the', 'DT'), ('inverses', 'NNS'), ('of', 'IN'), ('a', 'DT'), ('i.e.', 'NN'), (',', ','), ('a^', 'NN'), ('(', '('), ('-1', 'NNP'), (')', ')'), (']', 'VBP'), ('[', 'JJ'), ('#', '#'), ('Same', 'NNP'), ('a', 'DT'), ('above', 'IN'), ('using', 'VBG'), ('InvertingModulo', 'NNP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('add', 'VB'), ('function', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('add', 'VB'), ('function', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('add', 'VB'), ('function', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('equal', 'JJ'), ('to', 'TO'), ('the', 'DT'), ('length', 'NN'), ('of', 'IN'), ('original', 'JJ'), ('text', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('generated', 'VBN'), ('with', 'IN'), ('the', 'DT'), ('help', 'NN'), ('of', 'IN'), ('the', 'DT'), ('key', 'JJ'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('and', 'CC'), ('returns', 'VBZ'), ('the', 'DT'), ('original', 'JJ'), ('text', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Current', 'NNP'), ('minimum', 'JJ'), ('recommendation', 'NN'), ('is', 'VBZ'), ('2048', 'CD'), ('bit', 'NN'), ('(', '('), ('group', 'NN'), ('14', 'CD'), (')', ')'), (']', 'FW'), ('[', 'JJ'), ('#', '#'), ('and', 'CC'), ('it', 'PRP'), ('seems', 'VBZ'), ('to', 'TO'), ('run', 'VB'), ('nicely', 'RB'), ('!', '.')]
# [(']', 'JJ'), ('[', 'NNP'), ('#', '#'), ('query', 'NN'), ('with', 'IN'), ('O', 'NNP'), ('(', '('), ('lg', 'JJ'), ('n', 'NN'), (')', ')'), (']', 'VBZ'), ('[', 'JJ'), ('#', '#'), ('returns', 'NNS'), ('lca', 'NN'), ('of', 'IN'), ('node', 'JJ'), ('u', 'NN'), (',', ','), ('v', 'FW'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('runs', 'VBZ'), ('a', 'DT'), ('breadth', 'NN'), ('first', 'RB'), ('search', 'NN'), ('from', 'IN'), ('root', 'JJ'), ('node', 'NN'), ('of', 'IN'), ('the', 'DT'), ('tree', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('this', 'DT'), ('is', 'VBZ'), ('min-heapify', 'JJ'), ('method', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Used', 'VBN'), ('to', 'TO'), ('change', 'VB'), ('the', 'DT'), ('data', 'NN'), ('of', 'IN'), ('a', 'DT'), ('particular', 'JJ'), ('node', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('adding', 'VBG'), ('nodes', 'NNS'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('swapping', 'VBG'), ('nodes', 'NNS'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('A', 'NNP'), ('utility', 'NN'), ('function', 'NN'), ('to', 'TO'), ('print', 'VB'), ('elements', 'NNS'), ('of', 'IN'), ('array', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('for', 'IN'), ('calculating', 'VBG'), ('u', 'JJ'), ('value', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('function', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('f', 'NN'), ('(', '('), ('x', 'NNP'), (')', ')'), ('and', 'CC'), ('derivative', 'JJ'), ('is', 'VBZ'), ('the', 'DT'), ("''", "''"), ('f', 'NN'), ('(', '('), ('x', 'NN'), (')', ')'), ("''", "''"), (']', '$'), ('[', 'NNP'), ('#', '#'), ('Test', 'NNP'), (':', ':'), ('convert_to_negative', 'NN'), ('(', '('), (')', ')'), (']', 'VBP'), ('[', 'JJ'), ('#', '#'), ('Test', 'NN'), (':', ':'), ('change_contrast', 'NN'), ('(', '('), (')', ')'), (']', 'VBP'), ('[', 'JJ'), ('#', '#'), ('canny.gen_gaussian_kernel', 'NNS'), ('(', '('), (')', ')'), (']', 'VBP'), ('[', 'JJ'), ('#', '#'), ('canny.py', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('filtersgaussian_filter.py', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('returns', 'NNS'), ('(', '('), ('F', 'NNP'), ('(', '('), ('n', 'NN'), (')', ')'), (',', ','), ('F', 'NNP'), ('(', '('), ('n-1', 'JJ'), (')', ')'), (')', ')'), (']', 'VBP'), ('[', 'JJ'), ('#', '#'), ('Print', 'NNP'), ('order', 'NN'), ('of', 'IN'), ('matrix', 'NN'), ('with', 'IN'), ('Ai', 'NNP'), ('as', 'IN'), ('Matrix', 'NNP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Random', 'NNP'), ('population', 'NN'), ('created', 'VBD'), ('now', 'RB'), ("''", "''"), ('its', 'PRP$'), ("''", "''"), ('time', 'NN'), ('to', 'TO'), ('evaluate', 'VB'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Select', 'NNP'), (',', ','), ('Crossover', 'NNP'), ('and', 'CC'), ('Mutate', 'NNP'), ('a', 'DT'), ('new', 'JJ'), ('population', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Finding', 'NNP'), ('Articulation', 'NNP'), ('Points', 'NNP'), ('in', 'IN'), ('Undirected', 'NNP'), ('Graph', 'NNP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('function', 'NN'), ('to', 'TO'), ('search', 'VB'), ('the', 'DT'), ('path', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('find', 'VBP'), ('the', 'DT'), ('isolated', 'JJ'), ('node', 'NN'), ('in', 'IN'), ('the', 'DT'), ('graph', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('vertices', 'NNS'), ('of', 'IN'), ('same', 'JJ'), ('set', 'NN'), ('.', '.')]
# [(']', 'JJ'), ('[', 'NNP'), ('#', '#'), ('vertices', 'NNS'), ('of', 'IN'), ('same', 'JJ'), ('set', 'NN'), ('.', '.')]
# [(']', 'JJ'), ('[', 'NNP'), ('#', '#'), ('for', 'IN'), ('printing', 'VBG'), ('the', 'DT'), ('Graph', 'NNP'), ('vertices', 'NNS'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('for', 'IN'), ('adding', 'VBG'), ('the', 'DT'), ('edge', 'NN'), ('between', 'IN'), ('two', 'CD'), ('vertices', 'NNS'), (']', 'VBP'), ('[', 'RB'), ('#', '#'), ('Based', 'VBN'), ('on', 'IN'), ('Min', 'NNP'), ('Heap', 'NNP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('This', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('sample', 'NN'), ('depth', 'NN'), ('first', 'RB'), ('search', 'NN'), ('to', 'TO'), ('be', 'VB'), ('used', 'VBN'), ('at', 'IN'), ('max_flow', 'JJ'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Here', 'RB'), ('we', 'PRP'), ('calculate', 'VBP'), ('the', 'DT'), ('flow', 'NN'), ('that', 'WDT'), ('reaches', 'VBZ'), ('the', 'DT'), ('sink', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('handles', 'VBZ'), ('repetition', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('handles', 'NNS'), ('if', 'IN'), ('the', 'DT'), ('input', 'NN'), ('does', 'VBZ'), ('not', 'RB'), ('exist', 'VB'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('if', 'IN'), ('no', 'DT'), ('destination', 'NN'), ('is', 'VBZ'), ('meant', 'VBN'), ('the', 'DT'), ('default', 'NN'), ('value', 'NN'), ('is', 'VBZ'), ('-1', 'JJ'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('the', 'DT'), ('count', 'NN'), ('will', 'MD'), ('be', 'VB'), ('random', 'VBN'), ('from', 'IN'), ('10', 'CD'), ('to', 'TO'), ('10000', 'CD'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('handles', 'VBZ'), ('repetition', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('handles', 'NNS'), ('if', 'IN'), ('the', 'DT'), ('input', 'NN'), ('does', 'VBZ'), ('not', 'RB'), ('exist', 'VB'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('if', 'IN'), ('no', 'DT'), ('destination', 'NN'), ('is', 'VBZ'), ('meant', 'VBN'), ('the', 'DT'), ('default', 'NN'), ('value', 'NN'), ('is', 'VBZ'), ('-1', 'JJ'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('the', 'DT'), ('count', 'NN'), ('will', 'MD'), ('be', 'VB'), ('random', 'VBN'), ('from', 'IN'), ('10', 'CD'), ('to', 'TO'), ('10000', 'CD'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('make', 'VBP'), ('only', 'RB'), ('one', 'CD'), ('source', 'NN'), ('and', 'CC'), ('one', 'CD'), ('sink', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('You', 'PRP'), ('should', 'MD'), ('override', 'VB'), ('it', 'PRP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('using', 'VBG'), ('dfs', 'NN'), ('for', 'IN'), ('finding', 'VBG'), ('eulerian', 'JJ'), ('path', 'NN'), ('traversal', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('for', 'IN'), ('checking', 'VBG'), ('in', 'IN'), ('graph', 'NN'), ('has', 'VBZ'), ('euler', 'VBN'), ('path', 'NN'), ('or', 'CC'), ('circuit', 'NN'), (']', 'VBP'), ('[', 'JJ'), ('#', '#'), ('Finding', 'VBG'), ('Bridges', 'NNS'), ('in', 'IN'), ('Undirected', 'NNP'), ('Graph', 'NNP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Finding', 'NNP'), ('longest', 'JJS'), ('distance', 'NN'), ('in', 'IN'), ('Directed', 'NNP'), ('Acyclic', 'NNP'), ('Graph', 'NNP'), ('using', 'VBG'), ('KahnsAlgorithm', 'NNP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Disjoint', 'NNP'), ('Set', 'NNP'), ('Node', 'NNP'), ('to', 'TO'), ('store', 'VB'), ('the', 'DT'), ('parent', 'NN'), ('and', 'CC'), ('rank', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Disjoint', 'NNP'), ('Set', 'NNP'), ('DataStructure', 'NNP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Update', 'NNP'), ('function', 'NN'), ('if', 'IN'), ('value', 'NN'), ('of', 'IN'), ('any', 'DT'), ('node', 'NN'), ('in', 'IN'), ('min-heap', 'JJ'), ('decreases', 'NNS'), (']', 'VBP'), ('[', 'JJ'), ('#', '#'), ('PRNG', 'NNP'), ('(', '('), ('Xorshift', 'VBN'), ('by', 'IN'), ('George', 'NNP'), ('Marsaglia', 'NNP'), (')', ')'), (']', 'VBP'), ('[', 'JJ'), ('#', '#'), ('Functions', 'NNS'), ('of', 'IN'), ('binary', 'JJ'), ('conversion', 'NN'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':') ...
# [(']', 'JJ'), ('[', 'NNP'), ('#', '#'), ('Discrete', 'NNP'), ('fourier', 'JJR'), ('transform', 'NN'), ('of', 'IN'), ('A', 'NNP'), ('and', 'CC'), ('B', 'NNP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('multiply', 'VB'), ('the', 'DT'), ('DFTs', 'NNP'), ('of', 'IN'), ('A', 'NNP'), ('and', 'CC'), ('B', 'NNP'), ('and', 'CC'), ('find', 'VB'), ('A', 'NNP'), ('*', 'NNP'), ('B', 'NNP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Overwrite', 'NNP'), ('__str__', 'NN'), ('for', 'IN'), ('print', 'NN'), ('(', '('), (')', ')'), (';', ':'), ('Shows', 'VBZ'), ('A', 'NNP'), (',', ','), ('B', 'NNP'), ('and', 'CC'), ('A', 'NNP'), ('*', 'NNP'), ('B', 'NNP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('DarkCoder', 'NNP'), (']', 'NNP'), ('[', 'NNP'), ('class', 'NN'), ('matrix', 'NN'), (':', ':'), ('#', '#'), ('Public', 'NNP'), ('class', 'NN'), ('to', 'TO'), ('implement', 'VB'), ('a', 'DT'), ('graph', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('MATRIX', 'NNP'), ('INFORMATION', 'NNP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('MATRIX', 'NNP'), ('MANIPULATION', 'NNP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('MATRIX', 'NNP'), ('OPERATIONS', 'NNP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Make', 'NNP'), ('string', 'NN'), ('and', 'CC'), ('return', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Function', 'NNP'), ('to', 'TO'), ('print', 'VB'), ('upper', 'JJ'), ('half', 'NN'), ('of', 'IN'), ('diamond', 'NN'), ('(', '('), ('pyramid', 'NN'), (')', ')'), (']', 'VBZ'), ('[', 'JJ'), ('#', '#'), ('Function', 'NNP'), ('to', 'TO'), ('print', 'VB'), ('lower', 'JJR'), ('half', 'NN'), ('of', 'IN'), ('diamond', 'NN'), ('(', '('), ('pyramid', 'NN'), (')', ')'), (']', 'VBZ'), ('[', 'JJ'), ('#', '#'), ('Function', 'NNP'), ('to', 'TO'), ('print', 'VB'), ('complete', 'JJ'), ('diamond', 'NN'), ('pattern', 'NN'), ('of', 'IN'), ('``', '``'), ('*', 'JJ'), ("''", "''"), (']', 'NN'), ('[', 'NNP'), ('#', '#'), ('i=', 'VB'), ('how', 'WRB'), ('many', 'JJ'), ('letters', 'NNS'), ('or', 'CC'), ('characters', 'NNS'), ('the', 'DT'), ('password', 'NN'), ('length', 'NN'), ('will', 'MD'), ('be', 'VB'), (']', 'JJ'), ('[', 'NNP'), ('#', '#'), ('Function', 'NNP'), ('called', 'VBD'), ('at', 'IN'), ('each', 'DT'), ('step', 'NN'), ('of', 'IN'), ('the', 'DT'), ('animation', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('This', 'DT'), ('function', 'NN'), ('is', 'VBZ'), ('not', 'RB'), ('part', 'NN'), ('of', 'IN'), ('the', 'DT'), ('problem', 'NN'), (',', ','), ('I', 'PRP'), ('did', 'VBD'), ('it', 'PRP'), ('just', 'RB'), ('for', 'IN'), ('fun', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('the', 'DT'), ('builtin', 'NN'), ('functions', 'NNS'), ('.', '.')]
# [(']', 'JJ'), ('[', 'NNP'), ('#', '#'), ('small', 'JJ'), ('helper', 'NN'), ('function', 'NN'), ('for', 'IN'), ('modular', 'JJ'), ('exponentiation', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('iteration', 'NN'), ('version', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('iteration', 'NN'), ('over', 'IN'), ('the', 'DT'), ('unsorted', 'JJ'), ('list', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('creates', 'VBZ'), ('a', 'DT'), ('reverse', 'NN'), ('sorted', 'VBN'), ('list', 'NN'), ('and', 'CC'), ('sorts', 'VBZ'), ('it', 'PRP'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('BST', 'NNP'), ('data', 'NN'), ('structure', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Emission', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('last', 'JJ'), ('half', 'JJ'), ('hour', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Emissions', 'NNP'), ('in', 'IN'), ('a', 'DT'), ('specific', 'JJ'), ('date', 'NN'), ('range', 'NN'), (']', 'NNP'), ('[', 'NNP'), ('#', '#'), ('Get', 'NNP'), ('main', 'JJ'), ('domain', 'NN'), ('name', 'NN'), ('(', '('), ('example.com', 'NN'), (')', ')'), (']', 'VBZ'), ('[', 'JJ'), ('#', '#'), ('Get', 'NNP'), ('sub', 'JJ'), ('domain', 'NN'), ('name', 'NN'), ('(', '('), ('sub.example.com', 'NN'), (')', ')'), (']', 'NN')]

# %%
    # chunking
sentences = nltk.sent_tokenize(data2)
tokenized_sentences=[nltk.word_tokenize(sentence)for sentence in sentences]
tagged_sentences=[nltk.pos_tag(sentence) for sentence in tokenized_sentences]
chunked_sentences=nltk.ne_chunk_sents(tagged_sentences,binary=True)

def extract_entity_names(t):
    entity_name=[]
    
    if hasattr(t,'label') and t.label:
        if t.label()=='NE':
            entity_names.append(' '.join([child[0] for child in t]))
        else:
            for child in t:
                entity_name.extend(extract_entity_names(child))
    return entity_names

entity_names=[]
for tree in chunked_sentences:
    entity_names.extend(extract_entity_names(tree))
    
print(set(entity_names))
# Out:
# {'Mean Squared Error', 'Matrix', 'KKT', 'SMO', 'DarkCoder', 'ExtendedEuclid', 'Undirected Graph', 'BST', 'MATRIX', 'Comment', 'Disjoint Set Node', 'Random', 'Main Function', 'Disjoint Set', 'PRNG', 'Mean Absolute Error', 'DFTs', 'George Marsaglia', 'Directed Acyclic', 'InvertingModulo', 'Conquer', 'Mean Bias Deviation', 'KahnsAlgorithm', 'Crossover', 'Calculate Kernel'}
